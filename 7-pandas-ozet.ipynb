# %%
import pandas as pd

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status',
           'occupation', 'relationship', 'ethnicity', 'gender','capital_gain',
           'capital_loss', 'hours_per_week', 'country_of_origin','income']
# Veri seti UCI Machine Learning Repository'deki adult.data veri kümesinden yüklenir ve sütun adları atanır.

df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', names=columns)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week country_of_origin  income
# ...

# %%
# Veri kümesindeki sütunlar hakkında bilgi sağlayan info() metodu çağrılır.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   ethnicity       32561 non-null  object
#  9   gender          32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Veri kümesindeki eksik verilerin sayısı hesaplanır.

df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# ethnicity         0
# gender            0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.tail(12)
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation     relationship  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'ethnicity', 'gender',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'country_of_origin',
#        'income'],
#       dtype='object')

# %%
# "country_of_origin" sütununun adı "native_country" olarak değiştirilir.

df.rename(columns={"country_of_origin":"native_country"},inplace=True)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship ethnicity  \
# 0            Never-married        Adm-clerical   Not-in-family     White
# ...

# %%
# Veri kümesinin temel istatistiksel bilgileri sağlayan describe() metodu çağrılır.

df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# "occupation" sütunu seçilir ve yazdırılır.

df.occupation
# Out:
# 0              Adm-clerical
# 1           Exec-managerial
# 2         Handlers-cleaners
# 3         Handlers-cleaners
# 4            Prof-specialty
#                 ...
# 32556          Tech-support
# 32557     Machine-op-inspct
# 32558          Adm-clerical
# 32559          Adm-clerical
# 32560       Exec-managerial
# Name: occupation, Length: 32561, dtype: object

# %%
# "occupation" sütunu seçilir ve yazdırılır.

df["occupation"]
# Out:
# 0              Adm-clerical
# 1           Exec-managerial
# 2         Handlers-cleaners
# 3         Handlers-cleaners
# 4            Prof-specialty
#                 ...
# 32556          Tech-support
# 32557     Machine-op-inspct
# 32558          Adm-clerical
# 32559          Adm-clerical
# 32560       Exec-managerial
# Name: occupation, Length: 32561, dtype: object

# %%
# Her mesleğin kaç kez geçtiği sayılarla yazdırılır.
df["occupation"].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# İkinci satır seçilir ve yazdırılır.

df.iloc[1]
# Out:
# age                                50
# workclass            Self-emp-not-inc
# fnlwgt                          83311
# education                   Bachelors
# education_num                      13
# marital_status     Married-civ-spouse
# occupation            Exec-managerial
# relationship                  Husband
# ethnicity                       White
# gender                           Male
# capital_gain                        0
# capital_loss                        0
# hours_per_week                     13
# native_country          United-States
# income                          <=50K
# Name: 1, dtype: object

# %%
# İlk dört satır seçilir ve yazdırılır.
df.iloc[0:4]
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
#
#         marital_status          occupation    relationship ethnicity gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black   Male
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# ...

# %%
# 23. ve 24. satırlar seçilir ve yazdırılır.

df.iloc[23:25]
# Out:
#     age workclass  fnlwgt education  education_num       marital_status  \
# 23   43   Private  117037      11th              7   Married-civ-spouse
# 24   59   Private  109015   HS-grad              9             Divorced
#
#            occupation relationship ethnicity   gender  capital_gain  \
# 23   Transport-moving      Husband     White     Male             0
# 24       Tech-support    Unmarried     White   Female             0
#
#     capital_loss  hours_per_week  native_country  income
# 23          2042              40   United-States   <=50K
# 24             0              40   United-States   <=50K

# %%
# ilk 5 satırı getir
df.loc[0:4]
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship ethnicity   gender  \
# 0        Never-married        Adm-clerical   Not-in-family     White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife     Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
# İlk 5 satır, "age" ve "workclass" sütunları seçilerek yazdırılır.
df.loc[0:2,"age":"workclass"]
# Out:
#    age          workclass
# 0   39          State-gov
# 1   50   Self-emp-not-inc
# 2   38            Private

# %%
df["age"]>50
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558     True
# 32559    False
# 32560     True
# Name: age, Length: 32561, dtype: bool

# %%
# Yaşı 50'den büyük olan satırlar seçilir ve ilk 5 satır yazdırılır.

df[df["age"] > 50].head()
# Out:
#     age          workclass  fnlwgt   education  education_num  \
# 3    53            Private  234721        11th              7
# 7    52   Self-emp-not-inc  209642     HS-grad              9
# 21   54            Private  302146     HS-grad              9
# 24   59            Private  109015     HS-grad              9
# 25   56          Local-gov  216851   Bachelors             13
#
#          marital_status          occupation relationship ethnicity   gender  \
# 3    Married-civ-spouse   Handlers-cleaners      Husband     Black     Male
# 7    Married-civ-spouse     Exec-managerial      Husband     White     Male
# 21            Separated       Other-service    Unmarried     Black   Female
# 24             Divorced        Tech-support    Unmarried     White   Female
# 25   Married-civ-spouse        Tech-support      Husband     White     Male
#
#     capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
# Yaşı 50'den büyük olan satırlar seçilir ve "age", "workclass", "fnlwgt", "education", "education_num" sütunları seçilerek ilk 5 satır yazdırılır.

df.loc[df["age"] > 50,["age","workclass","fnlwgt","education","education_num"]].head()
# Out:
#     age          workclass  fnlwgt   education  education_num
# 3    53            Private  234721        11th              7
# 7    52   Self-emp-not-inc  209642     HS-grad              9
# 21   54            Private  302146     HS-grad              9
# 24   59            Private  109015     HS-grad              9
# 25   56          Local-gov  216851   Bachelors             13

# %%
# İlişki durumlarına göre gruplandırılarak her bir ilişki durumundaki satır sayısı yazdırılır.
df.groupby("relationship").count()
# Out:
#                    age  workclass  fnlwgt  education  education_num  \
# relationship
#  Husband         13193      13193   13193      13193          13193
#  Not-in-family    8305       8305    8305       8305           8305
#  Other-relative    981        981     981        981            981
#  Own-child        5068       5068    5068       5068           5068
#  Unmarried        3446       3446    3446       3446           3446
#  Wife             1568       1568    1568       1568           1568
#
#                  marital_status  occupation  ethnicity  gender  capital_gain  \
# relationship
#  Husband                  13193       13193      13193   13193         13193
#  Not-in-family             8305        8305       8305    8305          8305
#  Other-relative             981         981        981     981           981
#  Own-child                 5068        5068       5068    5068          5068
# ...

# %%
df.groupby(["education","age"])[["education_num","marital_status"]].mean()
# Out:
# C:\Users\Yusuf\AppData\Local\Temp\ipykernel_8756\2042990243.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["education","age"])[["education_num","marital_status"]].mean()
#                    education_num
# education     age
#  10th         17             6.0
#               18             6.0
#               19             6.0
#               20             6.0
#               21             6.0
# ...                          ...
#  Some-college 81            10.0
#               82            10.0
#               84            10.0
#               88            10.0
#               90            10.0
#
# [965 rows x 1 columns]
